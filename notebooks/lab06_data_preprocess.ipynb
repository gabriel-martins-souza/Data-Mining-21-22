# %%
# Remember: library imports are ALWAYS at the top of the script, no exceptions!
import sqlite3
import os
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.impute import KNNImputer

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (1.7.1)
# Collecting PyYAML>=5.0.0
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (3.4.2)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (3.0.1)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.8.2-cp39-cp39-win_amd64.whl (1.9 MB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.0-cp39-cp39-win_amd64.whl (659 kB)
# Requirement already satisfied: joblib~=1.0.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (1.0.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (1.20.3)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\gabriel.souza_ifood\appdata\roaming\python\python39\site-packages (from pandas-profiling) (2.24.0)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (2.0.1)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas-profiling) (1.3.2)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (21.2.0)
# Requirement already satisfied: Pillow in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (8.3.1)
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied: six in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.1)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gabriel.souza_ifood\appdata\roaming\python\python39\site-packages (from requests>=2.24.0->pandas-profiling) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gabriel.souza_ifood\appdata\roaming\python\python39\site-packages (from requests>=2.24.0->pandas-profiling) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.10)
# Requirement already satisfied: colorama in c:\users\gabriel.souza_ifood\anaconda3\envs\ml-env\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.4)
# Collecting PyWavelets
#   Downloading PyWavelets-1.1.1-cp39-cp39-win_amd64.whl (4.2 MB)
# Building wheels for collected packages: htmlmin, imagehash
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=17608c8ec9a47fc1a29f3f291b347341d8900cdaa9372be449bbcd0b1b21bd4d
#   Stored in directory: c:\users\gabriel.souza_ifood\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295207 sha256=b2772f416c940b2bba27746208ecb83e8e13cc9ffb13880c4f76da2a4456efa1
#   Stored in directory: c:\users\gabriel.souza_ifood\appdata\local\pip\cache\wheels\51\f9\a5\740af2fdb0ad1edf79aabdc41531be0b6f0b2e2be684c388cf
# Successfully built htmlmin imagehash
# Installing collected packages: tangled-up-in-unicode, PyWavelets, networkx, multimethod, visions, typing-extensions, imagehash, PyYAML, pydantic, phik, missingno, htmlmin, pandas-profiling
# Successfully installed PyWavelets-1.1.1 PyYAML-6.0 htmlmin-0.1.12 imagehash-4.2.1 missingno-0.5.0 multimethod-1.6 networkx-2.6.3 pandas-profiling-3.1.0 phik-0.12.0 pydantic-1.8.2 tangled-up-in-unicode-0.1.0 typing-extensions-3.10.0.2 visions-0.7.4

# %%
from pandas_profiling import ProfileReport

# %% [markdown]
# # Context
# The data we will be using through the pratical classes comes from a small relational database whose schema can be seen below:
# ![alt text](../figures/schema.png "Relation database schema")

# %% [markdown]
# # Reading the Data

# %%
# path to database
my_path = os.path.join("..", "data", "datamining.db")

# connect to the database
conn = sqlite3.connect(my_path)

# the query
query = """
select
    age, 
    income, 
    frq, 
    rcn, 
    mnt, 
    clothes, 
    kitchen, 
    small_appliances, 
    toys, 
    house_keeping,
    dependents, 
    per_net_purchase,
    g.gender, 
    e.education, 
    m.status, 
    r.description
from customers as c
    join genders as g on g.id = c.gender_id
    join education_levels as e on e.id = c.education_id
    join marital_status as m on m.id = c.marital_status_id
    join recommendations as r on r.id = c.recommendation_id
order by c.id;
"""

df = pd.read_sql_query(query, conn)

# %% [markdown]
# ## Make a copy of your original dataset
#
# why?

# %%
# CODE HERE
df_original = df.copy(deep=True)

# %% [markdown]
# # Metadata
# - *id* - The unique identifier of the customer
# - *age* - The year of birht of the customer
# - *income* - The income of the customer
# - *frq* - Frequency: number of purchases made by the customer
# - *rcn* - Recency: number of days since last customer purchase
# - *mnt* - Monetary: amount of € spent by the customer in purchases
# - *clothes* - Number of clothes items purchased by the customer
# - *kitchen* - Number of kitchen items purchased by the customer
# - *small_appliances* - Number of small_appliances items purchased by the customer
# - *toys* - Number of toys items purchased by the customer
# - *house_keeping* - Number of house_keeping items purchased by the customer
# - *dependents* - Binary. Whether or not the customer has dependents
# - *per_net_purchase* - Percentage of purchases made online
# - *education* - Education level of the customer
# - *status* - Marital status of the customer
# - *gender* - Gender of the customer
# - *description* - Last customer's recommendation description

# %% [markdown]
# ## Problems:
# - Duplicates?
# - Data types?
# - Missing values?
# - Strange values?
# - Descriptive statistics?
#
# ### Take a closer look and point out possible problems:
#
# (hint: a missing values in pandas is represented with a NaN value)

# %%
# replace "" by nans
df.replace("", np.nan, inplace=True)

# %%
# check dataset data types again
df.dtypes
# Out:
# age                   int64
# income              float64
# frq                   int64
# rcn                   int64
# mnt                   int64
# clothes               int64
# kitchen               int64
# small_appliances      int64
# toys                  int64
# house_keeping         int64
# dependents          float64
# per_net_purchase      int64
# gender               object
# education            object
# status               object
# description          object
# dtype: object

# %%
# check descriptive statistics again
df.describe(include="all").T
# Out:
#                    count unique         top  freq          mean           std  \
# age               8998.0    NaN         NaN   NaN    1966.05968     17.296552
# income            8952.0    NaN         NaN   NaN  69963.550827  27591.556226
# frq               8998.0    NaN         NaN   NaN     19.848077     10.903435
# rcn               8998.0    NaN         NaN   NaN     62.469771     69.761802
# mnt               8998.0    NaN         NaN   NaN    622.162814    646.768205
# clothes           8998.0    NaN         NaN   NaN     50.446655     23.422249
# kitchen           8998.0    NaN         NaN   NaN      7.039675      7.848139
# small_appliances  8998.0    NaN         NaN   NaN     28.524116     12.586437
# toys              8998.0    NaN         NaN   NaN      7.036897      7.924422
# house_keeping     8998.0    NaN         NaN   NaN      6.929984      7.882655
# dependents        8716.0    NaN         NaN   NaN      0.707205      0.455071
# per_net_purchase  8998.0    NaN         NaN   NaN     42.428984     18.495742
# gender              8998      2           M  5784           NaN           NaN
# education           8951      6  Graduation  4429           NaN           NaN
# status              8821      6     Married  3273           NaN           NaN
# description         8998      5    OK nice!  3434           NaN           NaN
#
#                       min      25%      50%      75%       max
# age                1936.0   1951.0   1966.0   1981.0    1996.0
# income            10000.0  47741.0  70030.5  92218.0  140628.0
# frq                   3.0     10.0     17.0     28.0      59.0
# rcn                   0.0     26.0     53.0     79.0     549.0
# mnt                   6.0     63.0    383.0   1076.0    3052.0
# clothes               1.0     33.0     51.0     69.0      99.0
# kitchen               0.0      2.0      4.0     10.0      75.0
# small_appliances      1.0     19.0     28.0     37.0      74.0
# toys                  0.0      2.0      4.0     10.0      62.0
# house_keeping         0.0      2.0      4.0      9.0      77.0
# dependents            0.0      0.0      1.0      1.0       1.0
# per_net_purchase      4.0     28.0     45.0     57.0      88.0
# gender                NaN      NaN      NaN      NaN       NaN
# education             NaN      NaN      NaN      NaN       NaN
# status                NaN      NaN      NaN      NaN       NaN
# description           NaN      NaN      NaN      NaN       NaN

# %%
#Define metric and non-metric features. Why?
non_metric_features = ["education", "status", "gender", "dependents", "description"]
metric_features = df.columns.drop(non_metric_features).to_list()

# %% [markdown]
# ## Fill missing values (Data imputation)
#
# How can we fill missing values?

# %%
# Creating a copy to apply central tendency measures imputation
df_central = df.copy()

# %%
# count of missing values
df_central.isna().sum()
# Out:
# age                   0
# income               46
# frq                   0
# rcn                   0
# mnt                   0
# clothes               0
# kitchen               0
# small_appliances      0
# toys                  0
# house_keeping         0
# dependents          282
# per_net_purchase      0
# gender                0
# education            47
# status              177
# description           0
# dtype: int64

# %%
df_central.median()
# Out:
# C:\Users\GABRIE~1.SOU\AppData\Local\Temp/ipykernel_13308/1469541937.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_central.median()
# age                  1966.0
# income              70030.5
# frq                    17.0
# rcn                    53.0
# mnt                   383.0
# clothes                51.0
# kitchen                 4.0
# small_appliances       28.0
# toys                    4.0
# house_keeping           4.0
# dependents              1.0
# per_net_purchase       45.0
# dtype: float64

# %%
# Check each step of these commands
modes = df_central[non_metric_features].mode().loc[0]
modes
# Out:
# education      Graduation
# status            Married
# gender                  M
# dependents            1.0
# description      OK nice!
# Name: 0, dtype: object

# %%
# Fill NaNs on df_central
df_central.fillna(modes,inplace = True)
df_central.fillna(df_central.median(),inplace=True)

df_central
# Out:
# C:\Users\GABRIE~1.SOU\AppData\Local\Temp/ipykernel_13308/1995486387.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_central.fillna(df_central.median(),inplace=True)
#        age    income  frq  rcn   mnt  clothes  kitchen  small_appliances  \
# 0     1946   90782.0   33   66  1402       37        5                44
# 1     1936  113023.0   32    6  1537       55        1                38
# 2     1990   28344.0   11   69    44       32       19                24
# 3     1955   93571.0   26   10   888       60       10                19
# 4     1955   91852.0   31   26  1138       59        5                28
# ...    ...       ...  ...  ...   ...      ...      ...               ...
# 8993  1960   94367.0   28    1   896       68        5                21
# 8994  1975   58121.0   12    6    61       53        6                28
# 8995  1986   54292.0   29   72  1011       41       11                36
# 8996  1938  125962.0   38   75  1668       61        2                25
# 8997  1994   26385.0    9   24    46        5       13                21
#
#       toys  house_keeping  dependents  per_net_purchase gender   education  \
# 0       10              3         0.0                19      M  Graduation
# 1        4              2         0.0                 9      F         PhD
# 2        1             24         1.0                59      M  Graduation
# 3        6              5         1.0                35      F      Master
# 4        4              4         1.0                34      F  Graduation
# ...    ...            ...         ...               ...    ...         ...
# 8993     3              4         1.0                55      F   1st Cycle
# 8994     7              6         1.0                71      M   2nd Cycle
# 8995     1             11         0.0                31      M  Graduation
# 8996     5              6         1.0                45      M   2nd Cycle
# 8997    46             15         1.0                52      M   1st Cycle
#
#         status      description
# 0     Together  Take my money!!
# 1     Divorced  Take my money!!
# 2      Married       Kind of OK
# 3      Married         OK nice!
# 4     Together  Take my money!!
# ...        ...              ...
# 8993    Single  Take my money!!
# 8994    Single           Meh...
# 8995  Together  Take my money!!
# 8996   Married  Take my money!!
# 8997    Single       Kind of OK
#
# [8998 rows x 16 columns]

# %%
df_central.isna().sum()
# Out:
# age                 0
# income              0
# frq                 0
# rcn                 0
# mnt                 0
# clothes             0
# kitchen             0
# small_appliances    0
# toys                0
# house_keeping       0
# dependents          0
# per_net_purchase    0
# gender              0
# education           0
# status              0
# description         0
# dtype: int64

# %%
# Creating new df copy to explore neighbordhood imputation
df_neighbors = df.copy()

# %%
# Seeing rows with NaNs
nans_index = df_neighbors.isna().any(axis=1)
df_neighbors[nans_index]
# Out:
#        age    income  frq  rcn   mnt  clothes  kitchen  small_appliances  \
# 3     1955   93571.0   26   10   888       60       10                19
# 61    1968       NaN   14   90   184       95        1                 3
# 67    1981   60457.0    9   73    63       37        2                51
# 70    1944  116259.0   28   35  1279       17        6                54
# 73    1967   75274.0   16   67   263       88        3                 6
# ...    ...       ...  ...  ...   ...      ...      ...               ...
# 8932  1959       NaN   20   71   716       67        5                25
# 8942  1950   92746.0   34   98  1399       50        5                36
# 8964  1978   44661.0    6   49    33       18       18                35
# 8972  1976       NaN   17    9   254       70        1                28
# 8992  1954   87399.0   25    1   837       56        8                27
#
#       toys  house_keeping  dependents  per_net_purchase gender   education  \
# 3        6              5         1.0                35      F      Master
# 61       1              0         1.0                59      F   2nd Cycle
# 67       6              3         NaN                57      M         PhD
# 70       3             20         0.0                11      M  Graduation
# 73       1              2         NaN                66      M  Graduation
# ...    ...            ...         ...               ...    ...         ...
# 8932     3              1         0.0                27      M  Graduation
# 8942     5              4         NaN                28      M      Master
# 8964    16             13         1.0                42      M   1st Cycle
# 8972     1              1         1.0                59      M  Graduation
# 8992     8              1         NaN                47      M  Graduation
#
#         status      description
# 3          NaN         OK nice!
# 61     Married           Meh...
# 67     Married           Meh...
# 70         NaN         OK nice!
# 73      Single       Kind of OK
# ...        ...              ...
# 8932   Married           Meh...
# 8942   Married  Take my money!!
# 8964       NaN         OK nice!
# 8972  Divorced           Meh...
# 8992   Married       Kind of OK
#
# [542 rows x 16 columns]

# %%
df_neighbors[metric_features]
# Out:
#        age    income  frq  rcn   mnt  clothes  kitchen  small_appliances  \
# 0     1946   90782.0   33   66  1402       37        5                44
# 1     1936  113023.0   32    6  1537       55        1                38
# 2     1990   28344.0   11   69    44       32       19                24
# 3     1955   93571.0   26   10   888       60       10                19
# 4     1955   91852.0   31   26  1138       59        5                28
# ...    ...       ...  ...  ...   ...      ...      ...               ...
# 8993  1960   94367.0   28    1   896       68        5                21
# 8994  1975   58121.0   12    6    61       53        6                28
# 8995  1986   54292.0   29   72  1011       41       11                36
# 8996  1938  125962.0   38   75  1668       61        2                25
# 8997  1994   26385.0    9   24    46        5       13                21
#
#       toys  house_keeping  per_net_purchase
# 0       10              3                19
# 1        4              2                 9
# 2        1             24                59
# 3        6              5                35
# 4        4              4                34
# ...    ...            ...               ...
# 8993     3              4                55
# 8994     7              6                71
# 8995     1             11                31
# 8996     5              6                45
# 8997    46             15                52
#
# [8998 rows x 11 columns]

# %%
# KNNImputer - only works for numerical variables. Fill NaNs on df_neighbors
imputer = KNNImputer(n_neighbors=5, weights="uniform")
df_neighbors[metric_features] = imputer.fit_transform(df_neighbors[metric_features])

# %%
df_neighbors.isna().sum()
# Out:
# age                   0
# income                0
# frq                   0
# rcn                   0
# mnt                   0
# clothes               0
# kitchen               0
# small_appliances      0
# toys                  0
# house_keeping         0
# dependents          282
# per_net_purchase      0
# gender                0
# education            47
# status              177
# description           0
# dtype: int64

# %%
# See rows with NaNs imputed
df_neighbors[nans_index]
# Out:
#          age    income   frq   rcn     mnt  clothes  kitchen  \
# 3     1955.0   93571.0  26.0  10.0   888.0     60.0     10.0
# 61    1968.0   63143.0  14.0  90.0   184.0     95.0      1.0
# 67    1981.0   60457.0   9.0  73.0    63.0     37.0      2.0
# 70    1944.0  116259.0  28.0  35.0  1279.0     17.0      6.0
# 73    1967.0   75274.0  16.0  67.0   263.0     88.0      3.0
# ...      ...       ...   ...   ...     ...      ...      ...
# 8932  1959.0   85643.4  20.0  71.0   716.0     67.0      5.0
# 8942  1950.0   92746.0  34.0  98.0  1399.0     50.0      5.0
# 8964  1978.0   44661.0   6.0  49.0    33.0     18.0     18.0
# 8972  1976.0   63932.4  17.0   9.0   254.0     70.0      1.0
# 8992  1954.0   87399.0  25.0   1.0   837.0     56.0      8.0
#
#       small_appliances  toys  house_keeping  dependents  per_net_purchase  \
# 3                 19.0   6.0            5.0         1.0              35.0
# 61                 3.0   1.0            0.0         1.0              59.0
# 67                51.0   6.0            3.0         NaN              57.0
# 70                54.0   3.0           20.0         0.0              11.0
# 73                 6.0   1.0            2.0         NaN              66.0
# ...                ...   ...            ...         ...               ...
# 8932              25.0   3.0            1.0         0.0              27.0
# 8942              36.0   5.0            4.0         NaN              28.0
# 8964              35.0  16.0           13.0         1.0              42.0
# 8972              28.0   1.0            1.0         1.0              59.0
# 8992              27.0   8.0            1.0         NaN              47.0
#
#      gender   education    status      description
# 3         F      Master       NaN         OK nice!
# 61        F   2nd Cycle   Married           Meh...
# 67        M         PhD   Married           Meh...
# 70        M  Graduation       NaN         OK nice!
# 73        M  Graduation    Single       Kind of OK
# ...     ...         ...       ...              ...
# 8932      M  Graduation   Married           Meh...
# 8942      M      Master   Married  Take my money!!
# 8964      M   1st Cycle       NaN         OK nice!
# 8972      M  Graduation  Divorced           Meh...
# 8992      M  Graduation   Married       Kind of OK
#
# [542 rows x 16 columns]

# %%
# let's keep the central imputation
df = df_central.copy()

# %% [markdown]
# ## An overview of our previous data exploration
#
# You can also explore this dataset using the exported `pandas-profiling` report.

# %% [markdown]
# ![](../figures/exp_analysis/categorical_variables_frequecies.png)
#
# ![](../figures/exp_analysis/numeric_variables_histograms.png)
#
# ![](../figures/exp_analysis/numeric_variables_boxplots.png)
#
# ![](../figures/exp_analysis/pairwise_relationship_of_numerical_variables.png)
#
# ![](../figures/exp_analysis/correlation_matrix.png)

# %% [markdown]
# ## Outlier removal
#
# Why do we need to remove outliers? Which methods can we use?
#
#
# Let's start by "manually" filtering the dataset's outliers

# %%
# This may vary from session to session, and is prone to varying interpretations.
# A simple example is provided below:

filters = (
    (df['house_keeping']<=50)
    &
    (df['kitchen']<=40)
    &
    (df['toys']<=35)
    &
    (df['education']!='OldSchool')
)

df_1 = df[filters]

# %%
print(df_1.shape)
print(df.shape)
# Out:
# (8817, 16)
# (8998, 16)

# %%
print('Percentage of data kept after removing outliers:', np.round(df_1.shape[0] / df_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.9799

# %% [markdown]
# ### Outlier removal using only the IQR method
#
# Why should you use/not use this method?

# %%
# Compute the IQR interquartile range
q25 = df.quantile(.25)  #quartile q1
q75 = df.quantile(.75)  #quartile q3
iqr = (q75 - q25)       #interquartile range


# Compute upper and lower limit (lower_limit = Q1 -1.5*IQR | upper_limit = Q3 + 1.5*IQR)
upper_lim = q75 + 1.5 * iqr
lower_lim = q25 - 1.5 * iqr

#
filters = []
for metric in metric_features:
    llim = lower_lim[metric]
    ulim = upper_lim[metric]
    filters.append(df[metric].between(llim, ulim, inclusive=True))

df_2 = df[np.all(filters, 0)]
print('Percentage of data kept after removing outliers:', np.round(df_2.shape[0] / df_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.8195
# C:\Users\GABRIE~1.SOU\AppData\Local\Temp/ipykernel_13308/1658216520.py:16: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   filters.append(df[metric].between(llim, ulim, inclusive=True))

# %%
# Get the manual filtering version
df = df_1.copy()

# %% [markdown]
# ## Feature extraction
#
# A reminder of our metadata:
# - *id* - The unique identifier of the customer
# - *age* - The year of birht of the customer
# - *income* - The income of the customer
# - *frq* - Frequency: number of purchases made by the customer
# - *rcn* - Recency: number of days since last customer purchase
# - *mnt* - Monetary: amount of € spent by the customer in purchases
# - *clothes* - Number of clothes items purchased by the customer
# - *kitchen* - Number of kitchen items purchased by the customer
# - *small_appliances* - Number of small_appliances items purchased by the customer
# - *toys* - Number of toys items purchased by the customer
# - *house_keeping* - Number of house_keeping items purchased by the customer
# - *dependents* - Binary. Whether or not the customer has dependents
# - *per_net_purchase* - Percentage of purchases made online
# - *education* - Education level of the customer
# - *status* - Marital status of the customer
# - *gender* - Gender of the customer
# - *description* - Last customer's recommendation description

# %%
# Try to pull as many features as you can; You can always drop them later on
# You can start by converting the 'age' variable to the actual age
# You can also store the birth year in another feature

df['birthyear'] = df['age']
df['age'] = 2021 - df['age']
df['mnt_net'] = df['per_net_purchase'] * df['mnt']
df.head()
# Out:
#    age    income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 0   75   90782.0   33   66  1402       37        5                44    10
# 1   85  113023.0   32    6  1537       55        1                38     4
# 2   31   28344.0   11   69    44       32       19                24     1
# 3   66   93571.0   26   10   888       60       10                19     6
# 4   66   91852.0   31   26  1138       59        5                28     4
#
#    house_keeping  dependents  per_net_purchase gender   education    status  \
# 0              3         0.0                19      M  Graduation  Together
# 1              2         0.0                 9      F         PhD  Divorced
# 2             24         1.0                59      M  Graduation   Married
# 3              5         1.0                35      F      Master       NaN
# 4              4         1.0                34      F  Graduation  Together
#
#        description  birthyear  mnt_net
# 0  Take my money!!       1946    26638
# 1  Take my money!!       1936    13833
# 2       Kind of OK       1990     2596
# 3         OK nice!       1955    31080
# 4  Take my money!!       1955    38692

# %% [markdown]
# ## Variable transform
# You may change the values of observations for a give variable:

# %%
# Remember the 'rcn' variable had an odd behavior? 
# This is the time to fix that

print((df['rcn']>100).value_counts())

rcn_t = df['rcn'].copy()
rcn_t.loc[rcn_t>100] = 100

df['rcn'] = rcn_t
# Out:
# False    8437
# True      380
# Name: rcn, dtype: int64

# %% [markdown]
# ## Handling highly correlated variables
#
# We already saw our original correlation matrix:
# ![](../figures/exp_analysis/correlation_matrix.png)

# %%
# Select variables according to their correlations

# CODE HERE

# %% [markdown]
# ## Redo data exploration
#
# Check if the data looks the way you expect it to.
#
# - Have you missed some outliers?
# - Are there still missing values?
# - Is the data normalized?
#
# This is an iterative process. It is likely you will change your preprocessing steps frequently throughout your group work.

# %%
ProfileReport(
    df,
    title='Tugas Customer Data Preprocessed',
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": False},
        "kendall": {"calculate": False},
        "phi_k": {"calculate": False},
        "cramers": {"calculate": False},
    },
)
